-- %%
CREATE VOLUME IF NOT EXISTS data.nobel_exo.nobel_volume;

-- %%
%python
DATA_PATH = "/Volumes/data/nobel_exo/nobel_volume"

df_nobel = spark.read.csv(f"{DATA_PATH}/complete.csv", header=True)

display(df_nobel)

-- %%
%python
df_nobel = spark.read.csv(f"{DATA_PATH}/complete.csv", header=True, inferSchema=True)
display(df_nobel)
