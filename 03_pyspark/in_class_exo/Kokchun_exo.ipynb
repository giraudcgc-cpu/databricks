-- %%
%sql 
SHOW CATALOGS;

SHOW SCHEMAS IN data;

CREATE SCHEMA IF NOT EXISTS data.nobel_exo2;

-- Fully qualitifed name: catalog.schema.volume
CREATE VOLUME IF NOT EXISTS data.nobel_exo2.nobel_volume2;

-- %%
%python
DATA_PATH = '/Volumes/data/nobel_exo2/nobel_volume2'

df = spark.read.csv(f"{DATA_PATH}/complete.csv", header=True, inferSchema=True)

df.limit(3).display()

df.take(2)
