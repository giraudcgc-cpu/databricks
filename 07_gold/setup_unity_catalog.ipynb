# %%
# %sql
CREATE CATALOG IF NOT EXISTS supply_chain_live2;

USE CATALOG supply_chain_live2;

CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;

CREATE VOLUME IF NOT EXISTS supply_chain_live2.default.raw;

# %%
# %python
dbutils.fs.mkdirs("/Volumes/supply_chain_live2/default/raw/data")
dbutils.fs.mkdirs("/Volumes/supply_chain_live2/default/raw/logs")
dbutils.fs.mkdirs("/Volumes/supply_chain_live2/default/raw/metadata")

# %%
from pyspark import as dp

BASE_DIR = '/Volumes/supply_chain_'
