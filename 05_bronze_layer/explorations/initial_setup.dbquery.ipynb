-- %%
SHOW CATALOGS;

CREATE CATALOG IF NOT EXISTS supply_chain_demo_cat;

USE CATALOG supply_chain_demo_cat;

CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;

--Volume will go to (inside) default like .default.raw
CREATE VOLUME IF NOT EXISTS raw;
